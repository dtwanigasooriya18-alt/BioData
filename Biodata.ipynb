# %%
print("I'm Dinithi Wanigasooriya.A 19 years old female living in Gampaha,Western Province,Sri lanka.")
# Out:
# I'm Dinithi Wanigasooriya.A 19 years old female living in Gampaha,Western Province,Sri lanka.

# %%
print("I've completed my O/Ls and A/Ls by 2025 December and currently expecting my A/L results.")
# Out:
# I've completed my O/Ls and A/Ls by 2025 December and currently expecting my A/L results.

# %%
print("I'm a tech and astrophysics enthuciast who is also interested in volunteering and public networking.")
# Out:
# I'm a tech and astrophysics enthuciast who is also interested in volunteering and public networking.

# %%
print("I have compering and public speaking skills coming from school activities.I'm also interested in trying new things coming my way and getting to know myself better.")
# Out:
# I have compering and public speaking skills coming from school activities.I'm also interested in trying new things coming my way and getting to know myself better.
